# %% [markdown]
# # In this project we are analyis the facial expression using keras (DEEP LEARNING) library.
# # In this project we are use online dataset for train our model. [Here the link of dataset](https://www.kaggle.com/ahmedmoorsy/facial-expression)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from keras.utils.np_utils import to_categorical
import pandas as pd
import numpy as np
import random
import sys
import warnings 
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline

#import brewer2mpl


def emotion_count(y_train, classes):
    """
    The function re-classify picture with disgust label into angry label
    """
    emo_classcount = {}
    print ('Disgust classified as Angry')
    y_train.loc[y_train == 1] = 0
    classes.remove('Disgust')
    for new_num, _class in enumerate(classes):
        y_train.loc[(y_train == emotion[_class])] = new_num
        class_count = sum(y_train == (new_num))
        emo_classcount[_class] = (new_num, class_count)
    return y_train.values, emo_classcount

def load_data(sample_split=0.3, usage='Training',classes=['Angry','Happy'], filepath='/content/gdrive/My Drive/fer2013.csv'):
    """
    The function load provided CSV dataset and further reshape, rescale the data for feeding
    """
    df = pd.read_csv(filepath)
    df = df[df.Usage == usage]
    frames = []
    classes.append('Disgust')
    for _class in classes:
        class_df = df[df['emotion'] == emotion[_class]]
        frames.append(class_df)
    data = pd.concat(frames, axis=0)
    rows = random.sample(list(data.index), int(len(data)*sample_split))
    data = data.loc[rows]
    x = list(data["pixels"])
    X = []
    for i in range(len(x)):
        each_pixel = [int(num) for num in x[i].split()]
        X.append(each_pixel)
    ## reshape into 48*48*1 and rescale
    X = np.array(X)
    X = X.reshape(X.shape[0], 48, 48,1)
    X = X.astype("float32")
    X /= 255
    
    y_train, new_dict = emotion_count(data.emotion, classes)
    y_train = to_categorical(y_train)
    return X, y_train
# Out:
# Using TensorFlow backend.

# %%
## All three datasets are well loaded accordingly
emotion = {'Angry': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3,
           'Sad': 4, 'Surprise': 5, 'Neutral': 6}
emo     = ['Angry', 'Fear', 'Happy',
           'Sad', 'Surprise', 'Neutral']

X_test, y_test = load_data(sample_split=1.0,classes=emo,
usage='PrivateTest')

X_train, y_train = load_data(sample_split=1.0,classes=emo,
usage= 'Training')

X_val,y_val = load_data(sample_split=1.0,classes=emo,
usage= 'PublicTest')
# Out:
# Disgust classified as Angry
# Disgust classified as Angry
# Disgust classified as Angry

# %%
## The shape of loaded data is under examination
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (28709, 48, 48, 1)
# (28709, 6)
# (3589, 48, 48, 1)
# (3589, 6)
# (3589, 48, 48, 1)
# (3589, 6)

# %%
def save_data(X_test, y_test, fname=''):
    """
    The function stores loaded data into numpy form for further processing
    """
    np.save( 'X_test' + fname, X_test)
    np.save( 'y_test' + fname, y_test)
save_data(X_test, y_test,"_privatetest6_100pct")
X_fname = 'X_test_privatetest6_100pct.npy'
y_fname = 'y_test_privatetest6_100pct.npy'
X = np.load(X_fname)
y = np.load(y_fname)
print ('Private test set')
y_labels = [np.argmax(lst) for lst in y]
counts = np.bincount(y_labels)
labels = ['angry', 'fear', 'happy', 'sad', 'surprise', 'neutral']
print (zip(labels, counts))
# Out:
# Private test set
# <zip object at 0x7ff02d0b0608>

# %%
def overview(start, end, X):
    """
    The function is used to plot first several pictures for overviewing inputs format
    """
    fig = plt.figure(figsize=(20,20))
    for i in range(start, end+1):
        input_img = X[i:(i+1),:,:,:]
        ax = fig.add_subplot(16,12,i+1)
        ax.imshow(input_img[0,:,:,0], cmap=plt.cm.gray)
        plt.xticks(np.array([]))
        plt.yticks(np.array([]))
        plt.tight_layout()
    plt.show()
overview(0,191, X)

# %%
## Similarly we canvisualize any input with self-defined index with following code
input_img = X[6:7,:,:,:] 
print (input_img.shape)
plt.imshow(input_img[0,:,:,0], cmap='gray')
plt.show()
# Out:
# (1, 48, 48, 1)

# %%
y_train = y_train 
y_public = y_val 
y_private = y_test 
y_train_labels  = [np.argmax(lst) for lst in y_train]
y_public_labels = [np.argmax(lst) for lst in y_public]
y_private_labels = [np.argmax(lst) for lst in y_private]

# %%
# !pip install brewer2mpl
# Out:
# Collecting brewer2mpl
#   Downloading https://files.pythonhosted.org/packages/84/57/00c45a199719e617db0875181134fcb3aeef701deae346547ac722eaaf5e/brewer2mpl-1.4.1-py2.py3-none-any.whl
# Installing collected packages: brewer2mpl
# Successfully installed brewer2mpl-1.4.1

# %%
import brewer2mpl

def plot_distribution(y1, y2, data_names, ylims =[1000,1000]): 
    """
    The function is used to plot the distribution of the labels of provided dataset 
    """
    colorset = brewer2mpl.get_map('Set3', 'qualitative', 6).mpl_colors
    fig = plt.figure(figsize=(8,4))
    ax1 = fig.add_subplot(1,2,1)
    ax1.bar(np.arange(1,7), np.bincount(y1), color=colorset, alpha=0.8)
    ax1.set_xticks(np.arange(1.25,7.25,1))
    ax1.set_xticklabels(labels, rotation=60, fontsize=14)
    ax1.set_xlim([0, 8])
    ax1.set_ylim([0, ylims[0]])
    ax1.set_title(data_names[0])
    
    ax2 = fig.add_subplot(1,2,2)
    ax2.bar(np.arange(1,7), np.bincount(y2), color=colorset, alpha=0.8)
    ax2.set_xticks(np.arange(1.25,7.24,1))
    ax2.set_xticklabels(labels, rotation=60, fontsize=14)
    ax2.set_xlim([0, 8])
    ax2.set_ylim([0, ylims[1]])
    ax2.set_title(data_names[1])
    plt.tight_layout()
    plt.show()
    
plot_distribution(y_train_labels, y_public_labels, \
                  ['Train dataset', 'Public dataset'], \
                  ylims =[8000,1000])

# %%
# Final Model Architecture:
from keras import layers
from keras import models
from keras import optimizers

modelN = models.Sequential()
modelN.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu',
                        input_shape=(48, 48, 1)))
modelN.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
modelN.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
modelN.add(layers.MaxPooling2D(pool_size=(2, 2)))

modelN.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
modelN.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
modelN.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
modelN.add(layers.MaxPooling2D(pool_size=(2, 2)))

modelN.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
modelN.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
modelN.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
modelN.add(layers.MaxPooling2D(pool_size=(2, 2)))

modelN.add(layers.Flatten())  # this converts our 3D feature maps to 1D feature vectors
modelN.add(layers.Dense(64, activation='relu'))
modelN.add(layers.Dense(64, activation='relu'))
modelN.add(layers.Dense(6, activation='softmax'))

# optimizer:
modelN.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print ('Training....')


#fit
nb_epoch = 100
batch_size = 128

modelF = modelN.fit(X_train, y_train, nb_epoch=nb_epoch, batch_size=batch_size,
          validation_data=(X_val, y_val), shuffle=True, verbose=1)
# Out:
# Training....
# Train on 28709 samples, validate on 3589 samples
# Epoch 1/100
# 28709/28709 [==============================] - 18s 628us/step - loss: 1.7529 - accuracy: 0.2513 - val_loss: 1.7049 - val_accuracy: 0.2683
# Epoch 2/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 1.5602 - accuracy: 0.3634 - val_loss: 1.4379 - val_accuracy: 0.4235
# Epoch 3/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 1.3751 - accuracy: 0.4545 - val_loss: 1.3218 - val_accuracy: 0.4812
# Epoch 4/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 1.2527 - accuracy: 0.5090 - val_loss: 1.2413 - val_accuracy: 0.5174
# Epoch 5/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 1.1558 - accuracy: 0.5499 - val_loss: 1.1703 - val_accuracy: 0.5442
# Epoch 6/100
# 28709/28709 [==============================] - 11s 387us/step - loss: 1.0819 - accuracy: 0.5825 - val_loss: 1.1687 - val_accuracy: 0.5542
# Epoch 7/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 1.0052 - accuracy: 0.6124 - val_loss: 1.1289 - val_accuracy: 0.5706
# Epoch 8/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.9267 - accuracy: 0.6493 - val_loss: 1.1635 - val_accuracy: 0.5587
# Epoch 9/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.8516 - accuracy: 0.6809 - val_loss: 1.1908 - val_accuracy: 0.5790
# Epoch 10/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.7536 - accuracy: 0.7186 - val_loss: 1.2295 - val_accuracy: 0.5737
# Epoch 11/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.6638 - accuracy: 0.7549 - val_loss: 1.2551 - val_accuracy: 0.5617
# Epoch 12/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.5718 - accuracy: 0.7914 - val_loss: 1.3919 - val_accuracy: 0.5740
# Epoch 13/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.4783 - accuracy: 0.8265 - val_loss: 1.5007 - val_accuracy: 0.5734
# Epoch 14/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.3886 - accuracy: 0.8587 - val_loss: 1.6903 - val_accuracy: 0.5612
# Epoch 15/100
# 28709/28709 [==============================] - 11s 391us/step - loss: 0.3473 - accuracy: 0.8748 - val_loss: 1.7803 - val_accuracy: 0.5667
# Epoch 16/100
# 28709/28709 [==============================] - 11s 393us/step - loss: 0.2728 - accuracy: 0.9025 - val_loss: 2.0601 - val_accuracy: 0.5690
# Epoch 17/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.2296 - accuracy: 0.9183 - val_loss: 2.2936 - val_accuracy: 0.5659
# Epoch 18/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.2063 - accuracy: 0.9275 - val_loss: 2.4285 - val_accuracy: 0.5670
# Epoch 19/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.1753 - accuracy: 0.9381 - val_loss: 2.3456 - val_accuracy: 0.5561
# Epoch 20/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.1636 - accuracy: 0.9433 - val_loss: 2.5333 - val_accuracy: 0.5626
# Epoch 21/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.1336 - accuracy: 0.9533 - val_loss: 2.9030 - val_accuracy: 0.5570
# Epoch 22/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.1281 - accuracy: 0.9553 - val_loss: 2.9362 - val_accuracy: 0.5587
# Epoch 23/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.1249 - accuracy: 0.9563 - val_loss: 3.1615 - val_accuracy: 0.5539
# Epoch 24/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.1133 - accuracy: 0.9611 - val_loss: 3.2171 - val_accuracy: 0.5665
# Epoch 25/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.1054 - accuracy: 0.9658 - val_loss: 3.4028 - val_accuracy: 0.5642
# Epoch 26/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.1074 - accuracy: 0.9634 - val_loss: 2.8444 - val_accuracy: 0.5612
# Epoch 27/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.1019 - accuracy: 0.9661 - val_loss: 3.1662 - val_accuracy: 0.5659
# Epoch 28/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.1016 - accuracy: 0.9658 - val_loss: 3.1196 - val_accuracy: 0.5575
# Epoch 29/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.1002 - accuracy: 0.9668 - val_loss: 3.4810 - val_accuracy: 0.5606
# Epoch 30/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0930 - accuracy: 0.9682 - val_loss: 3.3302 - val_accuracy: 0.5743
# Epoch 31/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0880 - accuracy: 0.9714 - val_loss: 3.4847 - val_accuracy: 0.5614
# Epoch 32/100
# 28709/28709 [==============================] - 11s 395us/step - loss: 0.0771 - accuracy: 0.9734 - val_loss: 3.4800 - val_accuracy: 0.5734
# Epoch 33/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0919 - accuracy: 0.9689 - val_loss: 3.1896 - val_accuracy: 0.5665
# Epoch 34/100
# 28709/28709 [==============================] - 11s 391us/step - loss: 0.0960 - accuracy: 0.9679 - val_loss: 3.3622 - val_accuracy: 0.5687
# Epoch 35/100
# 28709/28709 [==============================] - 11s 393us/step - loss: 0.0761 - accuracy: 0.9753 - val_loss: 3.4397 - val_accuracy: 0.5690
# Epoch 36/100
# 28709/28709 [==============================] - 11s 391us/step - loss: 0.0818 - accuracy: 0.9736 - val_loss: 3.3474 - val_accuracy: 0.5726
# Epoch 37/100
# 28709/28709 [==============================] - 11s 391us/step - loss: 0.0880 - accuracy: 0.9704 - val_loss: 3.4517 - val_accuracy: 0.5634
# Epoch 38/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0739 - accuracy: 0.9755 - val_loss: 3.3437 - val_accuracy: 0.5617
# Epoch 39/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0701 - accuracy: 0.9771 - val_loss: 3.3426 - val_accuracy: 0.5659
# Epoch 40/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0784 - accuracy: 0.9722 - val_loss: 3.4178 - val_accuracy: 0.5369
# Epoch 41/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0808 - accuracy: 0.9726 - val_loss: 3.6566 - val_accuracy: 0.5701
# Epoch 42/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0756 - accuracy: 0.9753 - val_loss: 3.5514 - val_accuracy: 0.5587
# Epoch 43/100
# 28709/28709 [==============================] - 11s 391us/step - loss: 0.0683 - accuracy: 0.9774 - val_loss: 3.2341 - val_accuracy: 0.5612
# Epoch 44/100
# 28709/28709 [==============================] - 11s 392us/step - loss: 0.0628 - accuracy: 0.9798 - val_loss: 3.4136 - val_accuracy: 0.5687
# Epoch 45/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0672 - accuracy: 0.9783 - val_loss: 3.5993 - val_accuracy: 0.5670
# Epoch 46/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0720 - accuracy: 0.9770 - val_loss: 3.6277 - val_accuracy: 0.5617
# Epoch 47/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0688 - accuracy: 0.9770 - val_loss: 3.6139 - val_accuracy: 0.5706
# Epoch 48/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0669 - accuracy: 0.9776 - val_loss: 3.8961 - val_accuracy: 0.5575
# Epoch 49/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0782 - accuracy: 0.9727 - val_loss: 3.3712 - val_accuracy: 0.5587
# Epoch 50/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0620 - accuracy: 0.9799 - val_loss: 3.8529 - val_accuracy: 0.5642
# Epoch 51/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0712 - accuracy: 0.9764 - val_loss: 3.8502 - val_accuracy: 0.5648
# Epoch 52/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0621 - accuracy: 0.9797 - val_loss: 3.7365 - val_accuracy: 0.5626
# Epoch 53/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0637 - accuracy: 0.9783 - val_loss: 3.7423 - val_accuracy: 0.5670
# Epoch 54/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0584 - accuracy: 0.9805 - val_loss: 4.0883 - val_accuracy: 0.5545
# Epoch 55/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0626 - accuracy: 0.9791 - val_loss: 3.7953 - val_accuracy: 0.5653
# Epoch 56/100
# 28709/28709 [==============================] - 11s 391us/step - loss: 0.0561 - accuracy: 0.9819 - val_loss: 3.8278 - val_accuracy: 0.5687
# Epoch 57/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0692 - accuracy: 0.9762 - val_loss: 3.4370 - val_accuracy: 0.5600
# Epoch 58/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0535 - accuracy: 0.9823 - val_loss: 3.5893 - val_accuracy: 0.5573
# Epoch 59/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0665 - accuracy: 0.9791 - val_loss: 3.5296 - val_accuracy: 0.5712
# Epoch 60/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0588 - accuracy: 0.9798 - val_loss: 3.9082 - val_accuracy: 0.5651
# Epoch 61/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0517 - accuracy: 0.9831 - val_loss: 3.9435 - val_accuracy: 0.5467
# Epoch 62/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0600 - accuracy: 0.9799 - val_loss: 3.9465 - val_accuracy: 0.5648
# Epoch 63/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0632 - accuracy: 0.9787 - val_loss: 3.5662 - val_accuracy: 0.5690
# Epoch 64/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0596 - accuracy: 0.9799 - val_loss: 3.7057 - val_accuracy: 0.5637
# Epoch 65/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0490 - accuracy: 0.9841 - val_loss: 4.0658 - val_accuracy: 0.5598
# Epoch 66/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0622 - accuracy: 0.9808 - val_loss: 3.7621 - val_accuracy: 0.5684
# Epoch 67/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0560 - accuracy: 0.9813 - val_loss: 3.5333 - val_accuracy: 0.5639
# Epoch 68/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0487 - accuracy: 0.9837 - val_loss: 3.7563 - val_accuracy: 0.5623
# Epoch 69/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0507 - accuracy: 0.9834 - val_loss: 3.8576 - val_accuracy: 0.5684
# Epoch 70/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0579 - accuracy: 0.9814 - val_loss: 4.1150 - val_accuracy: 0.5600
# Epoch 71/100
# 28709/28709 [==============================] - 11s 392us/step - loss: 0.0692 - accuracy: 0.9767 - val_loss: 3.2808 - val_accuracy: 0.5748
# Epoch 72/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0511 - accuracy: 0.9834 - val_loss: 3.8442 - val_accuracy: 0.5704
# Epoch 73/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0444 - accuracy: 0.9853 - val_loss: 3.9964 - val_accuracy: 0.5581
# Epoch 74/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0501 - accuracy: 0.9836 - val_loss: 4.3258 - val_accuracy: 0.5631
# Epoch 75/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0607 - accuracy: 0.9796 - val_loss: 3.7079 - val_accuracy: 0.5692
# Epoch 76/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0441 - accuracy: 0.9850 - val_loss: 4.2108 - val_accuracy: 0.5642
# Epoch 77/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0514 - accuracy: 0.9833 - val_loss: 4.1106 - val_accuracy: 0.5617
# Epoch 78/100
# 28709/28709 [==============================] - 11s 390us/step - loss: 0.0556 - accuracy: 0.9819 - val_loss: 4.0585 - val_accuracy: 0.5556
# Epoch 79/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0619 - accuracy: 0.9791 - val_loss: 4.1525 - val_accuracy: 0.5665
# Epoch 80/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0456 - accuracy: 0.9852 - val_loss: 4.3396 - val_accuracy: 0.5570
# Epoch 81/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0455 - accuracy: 0.9852 - val_loss: 3.8380 - val_accuracy: 0.5651
# Epoch 82/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0503 - accuracy: 0.9836 - val_loss: 4.0227 - val_accuracy: 0.5492
# Epoch 83/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0566 - accuracy: 0.9819 - val_loss: 3.8637 - val_accuracy: 0.5561
# Epoch 84/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0372 - accuracy: 0.9873 - val_loss: 4.3560 - val_accuracy: 0.5634
# Epoch 85/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0527 - accuracy: 0.9828 - val_loss: 3.9947 - val_accuracy: 0.5567
# Epoch 86/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0508 - accuracy: 0.9831 - val_loss: 3.7930 - val_accuracy: 0.5659
# Epoch 87/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0453 - accuracy: 0.9851 - val_loss: 4.0026 - val_accuracy: 0.5631
# Epoch 88/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0436 - accuracy: 0.9864 - val_loss: 3.6274 - val_accuracy: 0.5589
# Epoch 89/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0513 - accuracy: 0.9821 - val_loss: 3.9470 - val_accuracy: 0.5656
# Epoch 90/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0662 - accuracy: 0.9780 - val_loss: 3.8590 - val_accuracy: 0.5514
# Epoch 91/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0477 - accuracy: 0.9845 - val_loss: 4.0293 - val_accuracy: 0.5578
# Epoch 92/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0472 - accuracy: 0.9841 - val_loss: 4.1726 - val_accuracy: 0.5545
# Epoch 93/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0579 - accuracy: 0.9808 - val_loss: 3.7204 - val_accuracy: 0.5626
# Epoch 94/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0408 - accuracy: 0.9866 - val_loss: 4.0771 - val_accuracy: 0.5528
# Epoch 95/100
# 28709/28709 [==============================] - 11s 388us/step - loss: 0.0446 - accuracy: 0.9857 - val_loss: 4.0750 - val_accuracy: 0.5425
# Epoch 96/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0350 - accuracy: 0.9890 - val_loss: 4.1214 - val_accuracy: 0.5670
# Epoch 97/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0475 - accuracy: 0.9841 - val_loss: 3.9701 - val_accuracy: 0.5497
# Epoch 98/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0588 - accuracy: 0.9799 - val_loss: 4.3061 - val_accuracy: 0.5717
# Epoch 99/100
# 28709/28709 [==============================] - 11s 393us/step - loss: 0.0440 - accuracy: 0.9861 - val_loss: 3.7619 - val_accuracy: 0.5706
# Epoch 100/100
# 28709/28709 [==============================] - 11s 389us/step - loss: 0.0305 - accuracy: 0.9899 - val_loss: 4.2419 - val_accuracy: 0.5631

# %%
modelN.save('facial_1')

acc = modelF.history['accuracy']
val_acc = modelF.history['val_accuracy']
loss = modelF.history['loss']
val_loss = modelF.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# evaluate model on private test set
score = modelN.evaluate(X, y, verbose=0)
print ("model %s: %.2f%%" % (modelN.metrics_names[1], score[1]*100))
# Out:
# model accuracy: 58.07%

# %%
# prediction and true labels
y_prob = modelN.predict(X, batch_size=32, verbose=0)
y_pred = [np.argmax(prob) for prob in y_prob]
y_true = [np.argmax(true) for true in y]

# %%
import matplotlib.pyplot as matplotlib

def plot_subjects(start, end, y_pred, y_true, title=False):
    """
    The function is used to plot the picture subjects
    """
    fig = plt.figure(figsize=(12,12))
    emotion = {0:'Angry', 1:'Fear', 2:'Happy', 3:'Sad', 4:'Surprise', 5:'Neutral'}
    for i in range(start, end+1):
        input_img = X[i:(i+1),:,:,:]
        ax = fig.add_subplot(6,6,i+1)
        ax.imshow(input_img[0,:,:,0], cmap=matplotlib.cm.gray)
        plt.xticks(np.array([]))
        plt.yticks(np.array([]))
        if y_pred[i] != y_true[i]:
            plt.xlabel(emotion[y_true[i]], color='#53b3cb',fontsize=12)
        else:
            plt.xlabel(emotion[y_true[i]], fontsize=12)
        if title:
            plt.title(emotion[y_pred[i]], color='blue')
        plt.tight_layout()
    plt.show()

# %%
import brewer2mpl
def plot_probs(start,end, y_prob):
    """
    The function is used to plot the probability in histogram for six labels 
    """
    fig = plt.figure(figsize=(12,12))
    for i in range(start, end+1):
        input_img = X[i:(i+1),:,:,:]
        ax = fig.add_subplot(6,6,i+1)
        set3 = brewer2mpl.get_map('Set3', 'qualitative', 6).mpl_colors
        ax.bar(np.arange(0,6), y_prob[i], color=set3,alpha=0.5)
        ax.set_xticks(np.arange(0.5,6.5,1))
        labels = ['angry', 'fear', 'happy', 'sad', 'surprise','neutral']
        ax.set_xticklabels(labels, rotation=90, fontsize=10)
        ax.set_yticks(np.arange(0.0,1.1,0.5))
        plt.tight_layout()
    plt.show()

# %%
def plot_subjects_with_probs(start, end, y_prob):
    """
    This plotting function is used to plot the probability together with its picture
    """
    iter = int((end - start)/6)
    for i in np.arange(0,iter):
        plot_subjects(i*6,(i+1)*6-1, y_pred, y_true, title=False)
        plot_probs(i*6,(i+1)*6-1, y_prob)

# %%
plot_subjects_with_probs(0, 36, y_prob)

# %%
def plot_distribution2(y_true, y_pred):
    """
    The function is used to compare the number of true labels as well as prediction results
    """
    colorset = brewer2mpl.get_map('Set3', 'qualitative', 6).mpl_colors
    ind = np.arange(1.5,7,1)  # the x locations for the groups
    width = 0.35   
    fig, ax = plt.subplots()
    true = ax.bar(ind, np.bincount(y_true), width, color=colorset, alpha=1.0)
    pred = ax.bar(ind + width, np.bincount(y_pred), width, color=colorset, alpha=0.3)
    ax.set_xticks(np.arange(1.5,7,1))
    ax.set_xticklabels(labels, rotation=30, fontsize=14)
    ax.set_xlim([1.25, 7.5])
    ax.set_ylim([0, 1000])
    ax.set_title('True and Predicted Label Count (Private)')
    plt.tight_layout()
    plt.show()
    
plot_distribution2(y_true, y_pred)

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, cmap=plt.cm.Blues):
    """
    The function is used to construct the confusion matrix 
    """
    cm = confusion_matrix(y_true, y_pred)
    fig = plt.figure(figsize=(6,6))
    matplotlib.rcParams.update({'font.size': 16})
    ax  = fig.add_subplot(111)
    matrix = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    fig.colorbar(matrix) 
    for i in range(0,6):
        for j in range(0,6):  
            ax.text(j,i,cm[i,j],va='center', ha='center')
    ticks = np.arange(len(labels))
    ax.set_xticks(ticks)
    ax.set_xticklabels(labels, rotation=45)
    ax.set_yticks(ticks)
    ax.set_yticklabels(labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(y_true, y_pred, cmap=plt.cm.YlGnBu)
plt.show()
